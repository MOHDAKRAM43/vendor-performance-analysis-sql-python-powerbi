# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import logging
import time
from sqlalchemy import create_engine

# ✅ Step 1: Always create the 'logs' folder at the root of your project
os.makedirs("../logs", exist_ok=True)   # <-- go one level up from .ipynb_checkpoints

# ✅ Step 2: Configure logging to write in that folder
logging.basicConfig(
    filename="../logs/ingestion_db.log",  # <-- points to the correct location
    level=logging.DEBUG,
    format="%(asctime)s - %(levelname)s - %(message)s",
    filemode="a"
)

# ✅ Step 3: Create engine as usual
engine = create_engine('sqlite:///../inventory.db')  # optional: also move DB to project root

def ingest_db(df, table_name, engine):
    try:
        df.to_sql(table_name, engine, if_exists="append", index=False)
        logging.info(f"Data ingested successfully into {table_name}")
    except Exception as e:
        logging.error(f"Error during ingestion: {e}")
        raise

# %%
import pandas as pd
import os
from sqlalchemy import create_engine
import logging
import time 

logging.basicConfig(
    filename = "logs/ingestion_db.log",
    level = logging.DEBUG,
    format = "%(asctime)s - %(levelname)s - %(message)s",
    filemode = "a" 
)

engine = create_engine('sqlite:///inventory.db')

def ingest_db(df, table_name, engine):
    '''this function will ingest the dataframe into database table'''
    df.to_sql(table_name, con = engine, if_exists = 'replace', index = False)
    
def load_raw_data():
    ''' this function will load the CSVs as dataframe and ingest into db'''
    start = time.time()
    for file in os.listdir('C:\\Users\\Mohd Akram\\vendor performane'):
        if '.csv' in file:
            df = pd.read_csv('C:\\Users\\Mohd Akram\\vendor performane/'+file)
            logging.info(f'Ingesting {file} in db')
            ingest_db(df, file[:-4], engine)
    end = time.time()
    total_time = (end - start )/60
    logging.info('--------------Ingestion Complete----------------')

    logging.info(f'\nTotal Time Taken: {total_time} minutes')

if __name__ == '__main__':
    load_raw_data()
